# %% [markdown]
# <a href="https://colab.research.google.com/github/laienwu/WCS/blob/master/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import readms

# %%
--readms--
# Out:
#   File "<ipython-input-9-4b72416c077f>", line 1
#     --readms--
#               ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
url='http://bit.ly/uforeports'
df=pd.read_csv(url)

# %%
df1=df.copy()
print(df1.shape)
df1.describe(include='all')
# Out:
# (18241, 5)
#            City Colors Reported Shape Reported  State              Time
# count     18216            2882          15597  18241             18241
# unique     6476              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27

# %%
df1.drop(['Colors Reported', 'Shape Reported'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#                    City State             Time
# 0                Ithaca    NY   6/1/1930 22:00
# 1           Willingboro    NJ  6/30/1930 20:00
# 2               Holyoke    CO  2/15/1931 14:00
# 3               Abilene    KS   6/1/1931 13:00
# 4  New York Worlds Fair    NY  4/18/1933 19:00

# %%
df1.drop(1, axis=0, inplace=True)

# %%
url="http://bit.ly/imdbratings"
df=pd.read_csv(url)

# %%
df1=df.copy()
df1.describe(include='all')
# Out:
#         star_rating    title content_rating  genre    duration                                        actors_list
# count    979.000000      979            976    979  979.000000                                                979
# unique          NaN      975             12     16         NaN                                                969
# top             NaN  Dracula              R  Drama         NaN  [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq            NaN        2            460    278         NaN                                                  6
# mean       7.889785      NaN            NaN    NaN  120.979571                                                NaN
# std        0.336069      NaN            NaN    NaN   26.218010                                                NaN
# min        7.400000      NaN            NaN    NaN   64.000000                                                NaN
# 25%        7.600000      NaN            NaN    NaN  102.000000                                                NaN
# 50%        7.800000      NaN            NaN    NaN  117.000000                                                NaN
# 75%        8.100000      NaN            NaN    NaN  134.000000                                                NaN
# max        9.300000      NaN            NaN    NaN  242.000000                                                NaN

# %%
df1.sort_values('title')

# %%
df1.describe(exclude=["object"])

# %%
df1[(df1.duration.values >=120) & (df1.genre.values=='Drama')]
# Out:
#      star_rating                                 title content_rating  genre  duration                                        actors_list
# 9            8.9                            Fight Club              R  Drama       139  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
# 13           8.8                          Forrest Gump          PG-13  Drama       142    [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
# 16           8.7       One Flew Over the Cuckoo's Nest              R  Drama       133  [u'Jack Nicholson', u'Louise Fletcher', u'Mich...
# 17           8.7                         Seven Samurai        UNRATED  Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 22           8.7                 It's a Wonderful Life       APPROVED  Drama       130  [u'James Stewart', u'Donna Reed', u'Lionel Bar...
# 24           8.7                                 Se7en              R  Drama       127  [u'Morgan Freeman', u'Brad Pitt', u'Kevin Spac...
# 47           8.5                      Taare Zameen Par             PG  Drama       165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 50           8.5                       Cinema Paradiso              R  Drama       155  [u'Philippe Noiret', u'Enzo Cannavale', u'Anto...
# 51           8.5                        Apocalypse Now              R  Drama       153  [u'Martin Sheen', u'Marlon Brando', u'Robert D...
# 53           8.5                          The Prestige          PG-13  Drama       130  [u'Christian Bale', u'Hugh Jackman', u'Scarlet...
# 56           8.5                   The Lives of Others              R  Drama       137  [u'Ulrich M\xfche', u'Martina Gedeck', u'Sebas...
# 67           8.4                       American Beauty              R  Drama       122  [u'Kevin Spacey', u'Annette Bening', u'Thora B...
# 72           8.4                       Rang De Basanti      NOT RATED  Drama       157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 73           8.4               Jodaeiye Nader az Simin          PG-13  Drama       123  [u'Peyman Moaadi', u'Leila Hatami', u'Sareh Ba...
# 77           8.4                              Oldeuboi              R  Drama       120  [u'Min-sik Choi', u'Ji-tae Yu', u'Hye-jeong Ka...
# 83           8.4                 To Kill a Mockingbird      NOT RATED  Drama       129  [u'Gregory Peck', u'John Megna', u'Frank Overt...
# 89           8.4                                Swades      NOT RATED  Drama       189  [u'Shah Rukh Khan', u'Gayatri Joshi', u'Kishor...
# 95           8.4                         All About Eve       APPROVED  Drama       138  [u'Bette Davis', u'Anne Baxter', u'George Sand...
# 104          8.3                                 Ikiru      NOT RATED  Drama       143  [u'Takashi Shimura', u'Nobuo Kaneko', u"Shin'i...
# 108          8.3                            Metropolis      NOT RATED  Drama       153  [u'Brigitte Helm', u'Alfred Abel', u'Gustav Fr...
# 116          8.3          Mr. Smith Goes to Washington      NOT RATED  Drama       129  [u'James Stewart', u'Jean Arthur', u'Claude Ra...
# 130          8.3                             Chinatown              R  Drama       130  [u'Jack Nicholson', u'Faye Dunaway', u'John Hu...
# 132          8.3                 Judgment at Nuremberg      NOT RATED  Drama       186  [u'Spencer Tracy', u'Burt Lancaster', u'Richar...
# 139          8.3                     Good Will Hunting              R  Drama       126  [u'Robin Williams', u'Matt Damon', u'Ben Affle...
# 141          8.3              The Secret in Their Eyes              R  Drama       129  [u'Ricardo Dar\xedn', u'Soledad Villamil', u'P...
# 146          8.2                               Warrior          PG-13  Drama       140    [u'Tom Hardy', u'Nick Nolte', u'Joel Edgerton']
# 150          8.2                             Incendies              R  Drama       139  [u'Lubna Azabal', u'M\xe9lissa D\xe9sormeaux-P...
# 157          8.2                    Gone with the Wind              G  Drama       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 158          8.2                             Gone Girl              R  Drama       149  [u'Ben Affleck', u'Rosamund Pike', u'Neil Patr...
# 159          8.2           The Best Years of Our Lives         PASSED  Drama       172  [u'Fredric March', u'Dana Andrews', u'Myrna Loy']
# 166          8.2                       The Deer Hunter              R  Drama       182  [u'Robert De Niro', u'Christopher Walken', u'J...
# 180          8.2                          Hotel Rwanda          PG-13  Drama       121  [u'Don Cheadle', u'Sophie Okonedo', u'Joaquin ...
# 181          8.2                               Stalker      NOT RATED  Drama       163  [u'Alisa Freyndlikh', u'Aleksandr Kaydanovskiy...
# 184          8.2                   Fanny and Alexander              R  Drama       188  [u'Bertil Guve', u'Pernilla Allwin', u'Kristin...
# 185          8.2                               Network              R  Drama       121  [u'Faye Dunaway', u'William Holden', u'Peter F...
# 188          8.2                   The Grapes of Wrath      NOT RATED  Drama       129  [u'Henry Fonda', u'Jane Darwell', u'John Carra...
# 195          8.1                               Platoon              R  Drama       120  [u'Charlie Sheen', u'Tom Berenger', u'Willem D...
# 202          8.1  La leggenda del pianista sull'oceano              R  Drama       165  [u'Tim Roth', u'Pruitt Taylor Vince', u'Bill N...
# 203          8.1                                 8 1/2      NOT RATED  Drama       138  [u'Marcello Mastroianni', u'Anouk Aim\xe9e', u...
# 205          8.1                         Amores Perros              R  Drama       154  [u'Emilio Echevarr\xeda', u'Gael Garc\xeda Ber...
# 207          8.1      What Ever Happened to Baby Jane?       APPROVED  Drama       134  [u'Bette Davis', u'Joan Crawford', u'Victor Bu...
# 211          8.1                            Departures          PG-13  Drama       130  [u'Masahiro Motoki', u'Ry\xf4ko Hirosue', u'Ts...
# 213          8.1                   There Will Be Blood              R  Drama       158  [u'Daniel Day-Lewis', u'Paul Dano', u'Ciar\xe1...
# 219          8.1       Who's Afraid of Virginia Woolf?          TV-MA  Drama       131  [u'Elizabeth Taylor', u'Richard Burton', u'Geo...
# 221          8.1                               Solaris             PG  Drama       167  [u'Natalya Bondarchuk', u'Donatas Banionis', u...
# 223          8.1                          Paris, Texas              R  Drama       147  [u'Harry Dean Stanton', u'Nastassja Kinski', u...
# 226          8.1                               Boyhood              R  Drama       165  [u'Ellar Coltrane', u'Patricia Arquette', u'Et...
# 227          8.1                   Million Dollar Baby          PG-13  Drama       132  [u'Hilary Swank', u'Clint Eastwood', u'Morgan ...
# 251          8.1      The Man Who Shot Liberty Valance       APPROVED  Drama       123   [u'James Stewart', u'John Wayne', u'Vera Miles']
# 259          8.1                              The Help          PG-13  Drama       146  [u'Emma Stone', u'Viola Davis', u'Octavia Spen...
# 262          8.1                           The Hustler        UNRATED  Drama       134  [u'Paul Newman', u'Jackie Gleason', u'Piper La...
# 267          8.1                                  Jaws             PG  Drama       124  [u'Roy Scheider', u'Robert Shaw', u'Richard Dr...
# 270          8.1                       Wings of Desire          PG-13  Drama       128  [u'Bruno Ganz', u'Solveig Dommartin', u'Otto S...
# 284          8.1              A Streetcar Named Desire             PG  Drama       122  [u'Vivien Leigh', u'Marlon Brando', u'Kim Hunt...
# 288          8.1                           Sling Blade              R  Drama       135  [u'Billy Bob Thornton', u'Dwight Yoakam', u'J....
# 289          8.1        All Quiet on the Western Front        UNRATED  Drama       136     [u'Lew Ayres', u'Louis Wolheim', u'John Wray']
# 311          8.0                   Slumdog Millionaire              R  Drama       120  [u'Dev Patel', u'Freida Pinto', u'Saurabh Shuk...
# 316          8.0                                   JFK              R  Drama       189  [u'Kevin Costner', u'Gary Oldman', u'Jack Lemm...
# 318          8.0                              Magnolia              R  Drama       188  [u'Tom Cruise', u'Jason Robards', u'Julianne M...
# 323          8.0                                   Her              R  Drama       126  [u'Joaquin Phoenix', u'Amy Adams', u'Scarlett ...
# 325          8.0                              Rain Man              R  Drama       133  [u'Dustin Hoffman', u'Tom Cruise', u'Valeria G...
# 335          8.0                        Doctor Zhivago          PG-13  Drama       197  [u'Omar Sharif', u'Julie Christie', u'Geraldin...
# 337          8.0               All the President's Men              R  Drama       138  [u'Dustin Hoffman', u'Robert Redford', u'Jack ...
# 342          8.0                    Dead Poets Society             PG  Drama       128  [u'Robin Williams', u'Robert Sean Leonard', u'...
# 344          8.0                               Head-On              R  Drama       121  [u'Birol \xdcnel', u'Sibel Kekilli', u'G\xfcve...
# 355          8.0                        Secrets & Lies              R  Drama       136  [u'Timothy Spall', u'Brenda Blethyn', u'Phylli...
# 361          8.0                   Fiddler on the Roof              G  Drama       181        [u'Topol', u'Norma Crane', u'Leonard Frey']
# 364          8.0                       Rosemary's Baby              R  Drama       136  [u'Mia Farrow', u'John Cassavetes', u'Ruth Gor...
# 373          8.0                       My Name Is Khan          PG-13  Drama       165    [u'Shah Rukh Khan', u'Kajol', u'Sheetal Menon']
# 374          8.0                      Scent of a Woman              R  Drama       156  [u'Al Pacino', u"Chris O'Donnell", u'James Reb...
# 375          8.0                        Mulholland Dr.              R  Drama       147  [u'Naomi Watts', u'Laura Harring', u'Justin Th...
# 377          8.0                The Fault in Our Stars          PG-13  Drama       126  [u'Shailene Woodley', u'Ansel Elgort', u'Nat W...
# 390          8.0                 Letters from Iwo Jima              R  Drama       141  [u'Ken Watanabe', u'Kazunari Ninomiya', u'Tsuy...
# 392          8.0                                 Glory              R  Drama       122  [u'Matthew Broderick', u'Denzel Washington', u...
# 396          7.9                         Almost Famous              R  Drama       122  [u'Billy Crudup', u'Patrick Fugit', u'Kate Hud...
# 397          7.9                          The Notebook          PG-13  Drama       123  [u'Gena Rowlands', u'James Garner', u'Rachel M...
# 404          7.9                The Remains of the Day             PG  Drama       134  [u'Anthony Hopkins', u'Emma Thompson', u'John ...
# 415          7.9                    The Killing Fields              R  Drama       141  [u'Sam Waterston', u'Haing S. Ngor', u'John Ma...
# 428          7.9                              Le passe          PG-13  Drama       130  [u'B\xe9r\xe9nice Bejo', u'Tahar Rahim', u'Ali...
# 430          7.9                    Breaking the Waves              R  Drama       159  [u'Emily Watson', u'Stellan Skarsg\xe5rd', u'K...
# 431          7.9                            Mr. Nobody              R  Drama       141  [u'Jared Leto', u'Sarah Polley', u'Diane Kruger']
# 444          7.9                          My Fair Lady       APPROVED  Drama       170  [u'Audrey Hepburn', u'Rex Harrison', u'Stanley...
# 448          7.9                               Cabaret             PG  Drama       124  [u'Liza Minnelli', u'Michael York', u'Helmut G...
# 456          7.9             Blue Is the Warmest Color          NC-17  Drama       179  [u'L\xe9a Seydoux', u'Ad\xe8le Exarchopoulos',...
# 457          7.9                         Boogie Nights              R  Drama       155  [u'Mark Wahlberg', u'Julianne Moore', u'Burt R...
# 473          7.8                       Ordinary People              R  Drama       124  [u'Donald Sutherland', u'Mary Tyler Moore', u'...
# 476          7.8                                Hamlet          PG-13  Drama       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 477          7.8                                 Amour          PG-13  Drama       127  [u'Jean-Louis Trintignant', u'Emmanuelle Riva'...
# 485          7.8                            Black Book              R  Drama       145  [u'Carice van Houten', u'Sebastian Koch', u'Th...
# 504          7.8                     Empire of the Sun             PG  Drama       153  [u'Christian Bale', u'John Malkovich', u'Miran...
# 505          7.8                            About Time              R  Drama       123  [u'Domhnall Gleeson', u'Rachel McAdams', u'Bil...
# 508          7.8   The Curious Case of Benjamin Button          PG-13  Drama       166  [u'Brad Pitt', u'Cate Blanchett', u'Tilda Swin...
# 525          7.8                     Pride & Prejudice             PG  Drama       129  [u'Keira Knightley', u'Matthew Macfadyen', u'B...
# 526          7.8                                  Zulu        UNRATED  Drama       138  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 530          7.8                             Atonement              R  Drama       123  [u'Keira Knightley', u'James McAvoy', u'Brenda...
# 538          7.8                      The White Ribbon              R  Drama       144  [u'Christian Friedel', u'Ernst Jacobi', u'Leon...
# 540          7.8                      The Color Purple          PG-13  Drama       154  [u'Danny Glover', u'Whoopi Goldberg', u'Oprah ...
# 544          7.8                                  Argo              R  Drama       120  [u'Ben Affleck', u'Bryan Cranston', u'John Goo...
# 548          7.8                        The Experiment              R  Drama       120  [u'Moritz Bleibtreu', u'Christian Berkel', u'O...
# 558          7.8                              The Game              R  Drama       129  [u'Michael Douglas', u'Deborah Kara Unger', u'...
# 559          7.8                            Changeling              R  Drama       141    [u'Angelina Jolie', u'Colm Feore', u'Amy Ryan']
# 594          7.7                              Dead Man              R  Drama       121  [u'Johnny Depp', u'Gary Farmer', u'Crispin Glo...
# 603          7.7                A Very Long Engagement              R  Drama       133  [u'Audrey Tautou', u'Gaspard Ulliel', u'Jodie ...
# 606          7.7                       Black Hawk Down              R  Drama       144  [u'Josh Hartnett', u'Ewan McGregor', u'Tom Siz...
# 609          7.7                           Frost/Nixon              R  Drama       122  [u'Frank Langella', u'Michael Sheen', u'Kevin ...
# 620          7.7                               Titanic          PG-13  Drama       194  [u'Leonardo DiCaprio', u'Kate Winslet', u'Bill...
# 628          7.7                    Brokeback Mountain              R  Drama       134  [u'Jake Gyllenhaal', u'Heath Ledger', u'Michel...
# 634          7.7    Close Encounters of the Third Kind             PG  Drama       137  [u'Richard Dreyfuss', u'Fran\xe7ois Truffaut',...
# 635          7.7                           Match Point              R  Drama       124  [u'Scarlett Johansson', u'Jonathan Rhys Meyers...
# 644          7.7                          Philadelphia          PG-13  Drama       125  [u'Tom Hanks', u'Denzel Washington', u'Roberta...
# 645          7.7                 Sense and Sensibility             PG  Drama       131  [u'Emma Thompson', u'Kate Winslet', u'James Fl...
# 647          7.7                    La grande bellezza      NOT RATED  Drama       142  [u'Toni Servillo', u'Carlo Verdone', u'Sabrina...
# 659          7.7                       Sophie's Choice              R  Drama       150  [u'Meryl Streep', u'Kevin Kline', u'Peter MacN...
# 665          7.7                                Lolita      NOT RATED  Drama       152  [u'James Mason', u'Shelley Winters', u'Sue Lyon']
# 676          7.7                          Lost Highway              R  Drama       134  [u'Bill Pullman', u'Patricia Arquette', u'John...
# 678          7.7                        Les Miserables          PG-13  Drama       158  [u'Hugh Jackman', u'Russell Crowe', u'Anne Hat...
# 679          7.7                         Moulin Rouge!          PG-13  Drama       127  [u'Nicole Kidman', u'Ewan McGregor', u'John Le...
# 689          7.7                          Seven Pounds          PG-13  Drama       123  [u'Will Smith', u'Rosario Dawson', u'Woody Har...
# 702          7.6                 Jin ling shi san chai              R  Drama       146      [u'Christian Bale', u'Ni Ni', u'Xinyi Zhang']
# 705          7.6                              I Am Sam          PG-13  Drama       132  [u'Sean Penn', u'Michelle Pfeiffer', u'Dakota ...
# 706          7.6                  Fried Green Tomatoes          PG-13  Drama       130  [u'Kathy Bates', u'Jessica Tandy', u'Mary Stua...
# 716          7.6                        A Few Good Men              R  Drama       138  [u'Tom Cruise', u'Jack Nicholson', u'Demi Moore']
# 718          7.6                       The Kite Runner          PG-13  Drama       128  [u'Khalid Abdalla', u'Ahmad Khan Mahmoodzada',...
# 720          7.6                                Munich              R  Drama       164  [u'Eric Bana', u'Daniel Craig', u'Marie-Jos\xe...
# 721          7.6                 House of Sand and Fog              R  Drama       126  [u'Jennifer Connelly', u'Ben Kingsley', u'Ron ...
# 731          7.6                     The Thin Red Line              R  Drama       170     [u'Jim Caviezel', u'Sean Penn', u'Nick Nolte']
# 734          7.6         The Last Temptation of Christ              R  Drama       164  [u'Willem Dafoe', u'Harvey Keitel', u'Barbara ...
# 739          7.6                       The Hurt Locker              R  Drama       131  [u'Jeremy Renner', u'Anthony Mackie', u'Brian ...
# 755          7.6                         Lust, Caution          NC-17  Drama       157  [u'Tony Chiu Wai Leung', u'Wei Tang', u'Joan C...
# 760          7.6                    Enemy at the Gates              R  Drama       131     [u'Jude Law', u'Ed Harris', u'Joseph Fiennes']
# 762          7.6                       Little Children              R  Drama       136  [u'Kate Winslet', u'Jennifer Connelly', u'Patr...
# 768          7.6                            The Reader              R  Drama       124  [u'Kate Winslet', u'Ralph Fiennes', u'Bruno Ga...
# 770          7.6                        A Royal Affair              R  Drama       137  [u'Alicia Vikander', u'Mads Mikkelsen', u'Mikk...
# 777          7.6                        The Book Thief          PG-13  Drama       131  [u'Sophie N\xe9lisse', u'Geoffrey Rush', u'Emi...
# 785          7.6                             The Piano              R  Drama       121  [u'Holly Hunter', u'Harvey Keitel', u'Sam Neill']
# 813          7.6                           The Natural             PG  Drama       138  [u'Robert Redford', u'Robert Duvall', u'Glenn ...
# 827          7.5       The Wind That Shakes the Barley      NOT RATED  Drama       127  [u'Cillian Murphy', u'Padraic Delaney', u'Liam...
# 831          7.5                         Reign Over Me              R  Drama       124  [u'Adam Sandler', u'Don Cheadle', u'Jada Pinke...
# 834          7.5                       Life as a House              R  Drama       125  [u'Hayden Christensen', u'Kevin Kline', u'Kris...
# 838          7.5                             The Class          PG-13  Drama       128  [u'Fran\xe7ois B\xe9gaudeau', u'Agame Malembo-...
# 842          7.5                           Cloud Atlas              R  Drama       172      [u'Tom Hanks', u'Halle Berry', u'Hugh Grant']
# 845          7.5                      The Painted Veil          PG-13  Drama       125  [u'Naomi Watts', u'Edward Norton', u'Liev Schr...
# 849          7.5                             Quiz Show          PG-13  Drama       133  [u'Ralph Fiennes', u'John Turturro', u'Rob Mor...
# 851          7.5         The Bridges of Madison County          PG-13  Drama       135  [u'Clint Eastwood', u'Meryl Streep', u'Annie C...
# 854          7.5                               Miracle             PG  Drama       135  [u'Kurt Russell', u'Patricia Clarkson', u'Nath...
# 875          7.5                         Rust and Bone              R  Drama       120  [u'Marion Cotillard', u'Matthias Schoenaerts',...
# 877          7.5                   Legends of the Fall              R  Drama       133  [u'Brad Pitt', u'Anthony Hopkins', u'Aidan Qui...
# 879          7.5                 The Constant Gardener              R  Drama       129  [u'Ralph Fiennes', u'Rachel Weisz', u'Hubert K...
# 889          7.5                      Devil's Advocate              R  Drama       144  [u'Keanu Reeves', u'Al Pacino', u'Charlize The...
# 895          7.5                              Biutiful              R  Drama       148  [u'Javier Bardem', u'Maricel \xc1lvarez', u'Ha...
# 901          7.5                                 Babel              R  Drama       143  [u'Brad Pitt', u'Cate Blanchett', u'Gael Garc\...
# 910          7.5                                  2046              R  Drama       129  [u'Tony Chiu Wai Leung', u'Ziyi Zhang', u'Faye...
# 914          7.5                             The Judge              R  Drama       141  [u'Robert Downey Jr.', u'Robert Duvall', u'Ver...
# 922          7.5                                   Mud          PG-13  Drama       130  [u'Matthew McConaughey', u'Tye Sheridan', u'Ja...
# 923          7.5                   Across the Universe          PG-13  Drama       133  [u'Evan Rachel Wood', u'Jim Sturgess', u'Joe A...
# 941          7.4                      A Bridge Too Far             PG  Drama       175  [u'Sean Connery', u"Ryan O'Neal", u'Michael Ca...
# 945          7.4                          Take Shelter              R  Drama       120  [u'Michael Shannon', u'Jessica Chastain', u'Sh...
# 955          7.4                      Zero Dark Thirty              R  Drama       157  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
# 968          7.4                   The English Patient              R  Drama       162  [u'Ralph Fiennes', u'Juliette Binoche', u'Will...
# 973          7.4                 The Cider House Rules          PG-13  Drama       126  [u'Tobey Maguire', u'Charlize Theron', u'Micha...

# %%
print(__doc__)

import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

np.random.seed(0)

# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 1500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)

# ============
# Set up cluster parameters
# ============
plt.figure(figsize=(9 * 2 + 3, 12.5))
plt.subplots_adjust(left=.02, right=.98, bottom=.001, top=.96, wspace=.05,
                    hspace=.01)

plot_num = 1

default_base = {'quantile': .3,
                'eps': .3,
                'damping': .9,
                'preference': -200,
                'n_neighbors': 10,
                'n_clusters': 3}

datasets = [
    (noisy_circles, {'damping': .77, 'preference': -240,
                     'quantile': .2, 'n_clusters': 2}),
    (noisy_moons, {'damping': .75, 'preference': -220, 'n_clusters': 2}),
    (varied, {'eps': .18, 'n_neighbors': 2}),
    (aniso, {'eps': .15, 'n_neighbors': 2}),
    (blobs, {}),
    (no_structure, {})]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # update parameters with dataset-specific values
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    # normalize dataset for easier parameter selection
    X = StandardScaler().fit_transform(X)

    # estimate bandwidth for mean shift
    bandwidth = cluster.estimate_bandwidth(X, quantile=params['quantile'])

    # connectivity matrix for structured Ward
    connectivity = kneighbors_graph(
        X, n_neighbors=params['n_neighbors'], include_self=False)
    # make connectivity symmetric
    connectivity = 0.5 * (connectivity + connectivity.T)

    # ============
    # Create cluster objects
    # ============
    ms = cluster.MeanShift(bandwidth=bandwidth, bin_seeding=True)
    two_means = cluster.MiniBatchKMeans(n_clusters=params['n_clusters'])
    ward = cluster.AgglomerativeClustering(
        n_clusters=params['n_clusters'], linkage='ward',
        connectivity=connectivity)
    spectral = cluster.SpectralClustering(
        n_clusters=params['n_clusters'], eigen_solver='arpack',
        affinity="nearest_neighbors")
    dbscan = cluster.DBSCAN(eps=params['eps'])
    affinity_propagation = cluster.AffinityPropagation(
        damping=params['damping'], preference=params['preference'])
    average_linkage = cluster.AgglomerativeClustering(
        linkage="average", affinity="cityblock",
        n_clusters=params['n_clusters'], connectivity=connectivity)
    birch = cluster.Birch(n_clusters=params['n_clusters'])
    gmm = mixture.GaussianMixture(
        n_components=params['n_clusters'], covariance_type='full')

    clustering_algorithms = (
        ('MiniBatchKMeans', two_means),
        ('AffinityPropagation', affinity_propagation),
        ('MeanShift', ms),
        ('SpectralClustering', spectral),
        ('Ward', ward),
        ('AgglomerativeClustering', average_linkage),
        ('DBSCAN', dbscan),
        ('Birch', birch),
        ('GaussianMixture', gmm)
    )

    for name, algorithm in clustering_algorithms:
        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the " +
                "connectivity matrix is [0-9]{1,2}" +
                " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning)
            warnings.filterwarnings(
                "ignore",
                message="Graph is not fully connected, spectral embedding" +
                " may not work as expected.",
                category=UserWarning)
            algorithm.fit(X)

        t1 = time.time()
        if hasattr(algorithm, 'labels_'):
            y_pred = algorithm.labels_.astype(np.int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
        # add black color for outliers (if any)
        colors = np.append(colors, ["#000000"])
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plt.text(.99, .01, ('%.2fs' % (t1 - t0)).lstrip('0'),
                 transform=plt.gca().transAxes, size=15,
                 horizontalalignment='right')
        plot_num += 1

plt.show()
# Out:
# Automatically created module for IPython interactive environment
